# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shakilsustswe/Machine-Learning-Assignment/blob/master/Ml%20Lab%20Final/Image%20classification%20by%20CNN.ipynb)

# %% [markdown]
# **Problem statement**

# %% [markdown]
# The dataset comprises 5,863 JPEG X-Ray images and is categorised into two types (Pneumonia and Normal), organised into three folders: train, test, and val. Each folder contains subfolders for each image type.
#
# These chest X-ray images (anterior-posterior view) were sourced from paediatric patients aged one to five years at a renowned hospital. The X-rays were part of the routine clinical care of these patients.
#
# As a data scientist working in the healthcare industry, your task is to develop a convolutional neural network (CNN) model that can classify medical images into their respective categories. The model should be able to accurately identify the type of medical image shown in an image, based on the image itself.
#
# Dataset: https://drive.google.com/file/d/1219EeGE1XTJVXYaulynJSa3BXGsbNCLx/view?usp=sharing

# %% [markdown]
# **Libraries**

# %%
#Md Sabit Islam Bhuiya
#2018831061
import os
import glob
import cv2
import numpy as np
import pandas as pd
from PIL import Image
from pathlib import Path
from keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential, Model, load_model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, Activation
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import Callback, EarlyStopping
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
# %matplotlib inline

# %% [markdown]
# **Drive Mount**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Dataset unzip and path defined**

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive.zip" -d "/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1381_virus_2375.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1608_bacteria_4235.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person445_virus_916.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person302_bacteria_1430.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1188_bacteria_3137.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person353_virus_728.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person348_bacteria_1602.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1272_bacteria_3232.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1294_virus_2222.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person3_bacteria_12.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person124_virus_234.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person378_virus_761.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1478_bacteria_3848.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1446_bacteria_3740.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person23_bacteria_91.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person294_bacteria_1381.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person462_bacteria_1967.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1539_bacteria_4022.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1839_bacteria_4705.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person299_bacteria_1417.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1535_bacteria_4017.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1507_bacteria_3945.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1429_bacteria_3688.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1568_virus_2723.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1216_virus_2062.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person592_virus_1141.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person870_virus_1516.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person849_virus_1494.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1602_virus_2780.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1178_bacteria_3126.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person342_virus_702.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person612_bacteria_2477.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person107_virus_197.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1368_virus_2354.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person70_bacteria_343.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1618_bacteria_4258.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person579_virus_1123.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person297_bacteria_1400.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person309_virus_632.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person277_bacteria_1305.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person571_virus_1114.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person301_bacteria_1427.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1474_virus_2557.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person441_virus_896.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1203_bacteria_3154.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1500_bacteria_3916.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1628_bacteria_4297.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person682_virus_1273.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person639_virus_1220.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person540_bacteria_2271.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person76_bacteria_372.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person599_bacteria_2455.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1679_bacteria_4450.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1338_bacteria_3397.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1502_bacteria_3922.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person959_bacteria_2884.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1366_virus_2349.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1352_bacteria_3445.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person51_bacteria_244.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person337_bacteria_1565.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person648_bacteria_2540.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person509_bacteria_2146.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1452_virus_2484.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1725_bacteria_4550.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person25_bacteria_113.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1039_bacteria_2973.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person558_bacteria_2328.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person137_virus_281.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person502_bacteria_2120.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person287_bacteria_1355.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person401_virus_797.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1482_virus_2570.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1557_bacteria_4063.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1512_virus_2631.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person292_virus_602.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person507_virus_1019.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person891_virus_1541.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person573_virus_1116.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1147_virus_1917.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person384_bacteria_1755.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1397_virus_2400.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person479_virus_978.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person339_bacteria_1572.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person888_bacteria_2812.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1912_bacteria_4817.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person625_bacteria_2500.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person757_bacteria_2661.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person779_bacteria_2683.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/
jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1400_bacteria_3550.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person550_virus_1090.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1306_virus_2249.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person281_bacteria_1332.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person383_bacteria_1750.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person458_bacteria_1954.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1008_virus_1691.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person563_bacteria_2338.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person67_bacteria_330.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person525_bacteria_2216.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person419_virus_857.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1725_bacteria_4551.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person502_bacteria_2121.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1145_virus_1902.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1482_virus_2571.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person287_bacteria_1354.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1719_bacteria_4544.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1162_virus_1950.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1517_bacteria_3968.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person273_virus_561.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person1181_virus_2016.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person672_bacteria_2565.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/PNEUMONIA/person374_bacteria_1712.jpeg
# ...
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0686-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0365-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0479-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1008-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0462-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0979-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0654-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0635-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1244-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0129-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0403-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1302-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0290-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1134-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0545-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0418-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0903-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0845-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0583-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0851-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0898-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0917-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0598-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0551-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0533-0001-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1120-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1316-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0417-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1250-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0629-0001-0003.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0621-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1154-0001-0002.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0640-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0689-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0476-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0530-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0147-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0371-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0692-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0237-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0327-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0261-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0616-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0656-0001-0002.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0799-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0566-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0507-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1176-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1030-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0488-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0441-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1206-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0394-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0677-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0807-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0941-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0988-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0493-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0487-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0955-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0678-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0508-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0349-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0663-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0455-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1024-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1162-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0513-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0869-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0572-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0744-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0602-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0275-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1118-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0569-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0333-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0619-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1116-0001-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1103-0001-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1269-0001-0002.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0690-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0659-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0974-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0529-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0832-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1005-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0474-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0642-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0368-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0532-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0704-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0765-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0553-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0881-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0848-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0545-0001-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0623-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0467-0001-0002.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0415-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0548-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0581-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1280-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0312-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0306-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1294-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0289-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0240-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0437-0001-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0595-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0401-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0637-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0895-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0547-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0771-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0710-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1157-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0526-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0656-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1227-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0183-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0460-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1011-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0826-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0960-0001.jpeg
#    creating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/
#    creating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/
#    creating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/person1950_bacteria_4881.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/person1951_bacteria_4882.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/person1952_bacteria_4883.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/person1946_bacteria_4874.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/person1947_bacteria_4876.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/person1946_bacteria_4875.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/person1949_bacteria_4880.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/PNEUMONIA/person1954_bacteria_4886.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1440-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1437-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1431-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1436-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1430-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1438-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1442-0001.jpeg
#   inflating: /content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1427-0001.jpeg

# %% [markdown]
# **Dataset directory**

# %%
img_dir = os.path.join("/content/drive/MyDrive/Colab Notebooks/ML Assignment", 'Archive')

# %%
print(os.listdir("/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive"))
# Out:
# ['test', '__MACOSX', 'train', 'val']

# %%
data_dir=Path('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive')
test_dir = data_dir/'test'
train_dir = data_dir/'train'
val_dir = data_dir/'val'

# %% [markdown]
# **Load Train Data**

# %%
def load_train():
    normal_cases_dir=train_dir/'NORMAL'
    pneumonia_cases_dir = train_dir/'PNEUMONIA'
    # Get the list of all the images
    normal_cases = normal_cases_dir.glob('*.jpeg')
    pneumonia_cases = pneumonia_cases_dir.glob('*.jpeg')
    train_data=[]
    train_label=[]
    for img in normal_cases:
            train_data.append(img)
            train_label.append('NORMAL')
    for img in pneumonia_cases:
            train_data.append(img)
            train_label.append("PNEUMONIA")
    df=pd.DataFrame(train_data)
    df.columns=['images']
    df['labels']=train_label
    df=df.sample(frac=1).reset_index(drop=True)
    return df

# %%
train_data=load_train()
train_data.shape
# Out:
# (5216, 2)

# %% [markdown]
# **Plot Train Data**

# %%
plt.bar(train_data['labels'].value_counts().index,train_data['labels'].value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %%
tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# **Train Directory**

# %%
os.listdir(train_dir)
# Out:
# ['.DS_Store', 'PNEUMONIA', 'NORMAL']

# %%
train_normal_dir = train_dir /"NORMAL"
train_pneumonia_dir = train_dir /"PNEUMONIA"

# %% [markdown]
# **Data Loading for Validation Dataset**

# %%
os.listdir(val_dir)
# Out:
# ['PNEUMONIA', 'NORMAL']

# %%
valid_normal_dir = val_dir /"NORMAL"
valid_pneumonia_dir = val_dir /"PNEUMONIA"

# %% [markdown]
# **Data Loading for Test Dataset**

# %%
os.listdir(test_dir)
# Out:
# ['.DS_Store', 'PNEUMONIA', 'NORMAL']

# %%
test_normal_dir = test_dir /"NORMAL"
test_pneumonia_dir = test_dir /"PNEUMONIA"

# %% [markdown]
# **Labeling**
#
# Setting the dataset for training

# %%
train_normal= train_normal_dir.glob("*.jpeg")
train_pneumonia=train_pneumonia_dir.glob("*.jpeg")
train_set=[]

# %%
for img in train_normal:
  train_set.append((img, 0))
for img in train_pneumonia:
  train_set.append((img, 1))

# %%
print(train_set[:5])
# Out:
# [(PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-0927-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1056-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0427-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/NORMAL2-IM-1260-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/train/NORMAL/IM-0656-0001-0001.jpeg'), 0)]

# %%
train_set=pd.DataFrame(train_set, columns=["image", "label"], index=None)
train_set.head()
# Out:
#                                                image  label
# 0  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 1  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 2  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 3  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 4  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0

# %%
#to shuffle all the rows in dataframe so that we can see normal and pneumonia in random
train_set=train_set.sample(frac=1)
#to set the indexes as if first time
train_set=train_set.reset_index(drop=True)
train_set.head()
# Out:
#                                                image  label
# 0  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 1  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 2  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 3  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 4  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0

# %% [markdown]
# Setting the dataset for valdiation

# %%
#to take the normal images from validation set
valid_normal= valid_normal_dir.glob("*.jpeg")
#to take the pneumonia images from the validation set
valid_pneumonia=valid_pneumonia_dir.glob("*.jpeg")
#to add all the validation data into one list, we created a blank list
valid_set=[]

#to add every image of normals in validationset to the list
for img in valid_normal:
  valid_set.append((img, 0))#we add 0 with normal images as label

#to add every image of pneumonias in validationset to the list
for img in valid_pneumonia:
  valid_set.append((img, 1)) #we add 1 with pneumonia images as label

#to check what our list look like
print(valid_set[:5])
# Out:
# [(PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1440-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1437-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1431-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1436-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/val/NORMAL/NORMAL2-IM-1430-0001.jpeg'), 0)]

# %%
#to create a dataframe from the list, so that we can use dataframe features
valid_set=pd.DataFrame(valid_set, columns=["image", "label"], index=None)
#to see the first 5 rows of our dataframe, only normals
valid_set.head()
# Out:
#                                                image  label
# 0  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 1  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 2  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 3  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 4  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0

# %%
#to shuffle all the rows in dataframe so that we can see normal and pneumonia in random
valid_set=valid_set.sample(frac=1)
 #to set the indexes as if first time

valid_set=valid_set.reset_index(drop=True)
valid_set.head()
# Out:
#                                                image  label
# 0  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 1  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 2  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 3  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 4  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1

# %% [markdown]
# Setting the dataset for test

# %%
test_normal= test_normal_dir.glob("*.jpeg")
test_pneumonia=test_pneumonia_dir.glob("*.jpeg")
test_set=[]
for img in test_normal:
  test_set.append((img, 0))
for img in test_pneumonia:
  test_set.append((img, 1))
print(test_set[:5])
# Out:
# [(PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/test/NORMAL/IM-0031-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/test/NORMAL/IM-0025-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/test/NORMAL/NORMAL2-IM-0272-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/test/NORMAL/NORMAL2-IM-0102-0001.jpeg'), 0), (PosixPath('/content/drive/MyDrive/Colab Notebooks/ML Assignment/Archive/test/NORMAL/NORMAL2-IM-0229-0001.jpeg'), 0)]

# %%
test_set=pd.DataFrame(test_set, columns=["image", "label"], index=None)
test_set.head()
# Out:
#                                                image  label
# 0  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 1  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 2  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 3  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0
# 4  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0

# %%
test_set=test_set.sample(frac=1)
test_set=test_set.reset_index(drop=True)
test_set.head()
# Out:
#                                                image  label
# 0  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 1  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 2  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 3  /content/drive/MyDrive/Colab Notebooks/ML Assi...      1
# 4  /content/drive/MyDrive/Colab Notebooks/ML Assi...      0

# %% [markdown]
# # Visualization

# %%
# Normal Image
train_normal_count = train_set.loc[train_set["label"]==0]["image"].count()
print("Total number of normal images:", train_normal_count)
# Out:
# Total number of normal images: 1341

# %%
print(train_normal_count)
# Out:
# 1341

# %%
# Pneumonia Image
train_pneumonia_count = train_set.loc[train_set["label"]==1]["image"].count()
print("Total number of pneumonia images:", train_pneumonia_count)
# Out:
# Total number of pneumonia images: 3875

# %%
print(train_pneumonia_count)
# Out:
# 3875

# %%
# plt.subplots(train_normal_count,train_pneumonia_count)
# plt.show()

# %%
from matplotlib.pyplot import imread
# Get few samples for both the classes
pneumonia_samples = (train_set[train_set["label"] == 1]["image"].iloc[:10]).tolist()
normal_samples = (train_set[train_set["label"] == 0]["image"].iloc[:10]).tolist()

# Concate the data in a single list and del the above two list
samples = pneumonia_samples + normal_samples
del pneumonia_samples, normal_samples

# Plot the data
f, ax = plt.subplots(2,5, figsize = (30,10))
for i in range(10):
    img = imread(samples[i])
    ax[i//5, i % 5].imshow(img, cmap='gray')
    if i < 5:
        ax[i//5, i % 5].set_title("PNEUMONIA")
    else:
        ax[i//5, i % 5].set_title("NORMAL")
    ax[i//5, i % 5].axis('off')
    ax[i//5, i % 5].set_aspect('auto')
plt.show()

# %%
print(train_pneumonia_count)
# Out:
# 3875

# %%
fig1,ax1= plt.subplots()
sizes = [train_normal_count, train_pneumonia_count]
ax1.pie(sizes, startangle=46 ,labels=["Normal lungs","Pneumonic lungs"], autopct="%1.1f%%", shadow=True, colors=["b","#F20741"])
ax1.axis("equal")
plt.legend()
plt.show()

# %%
fig2, ax2=plt.subplots()
ax2.bar(height=sizes, x=["Normal lungs", "Pneumonic lungs"], color=["blue", "#F20741"])
plt.title("Case Distribution")
# Out:
# Text(0.5, 1.0, 'Case Distribution')

# %% [markdown]
# # Data Preparation
#
# **Data Distribution**

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150


def get_training_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                # Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
#Get data
train = get_training_data(train_dir)
test = get_training_data(test_dir)
val = get_training_data(val_dir)
# Out:
# <ipython-input-50-0096977fee49>:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data)

# %%
# initialize multiple lists
X_train, X_val, X_test = ([], ) * 3
y_train, y_val, y_test = ([], ) * 3

for feature, label in train:
    X_train.append(feature)
    y_train.append(label)

for feature, label in val:
    X_val.append(feature)
    y_val.append(label)

for feature, label in test:
    X_test.append(feature)
    y_test.append(label)

# %% [markdown]
# **Data Normalization**

# %%
X_train = np.array(X_train) /255
X_val = np.array(X_val) / 255
X_test = np.array(X_test) / 255

# %% [markdown]
# **Reshaping the data**

# %%
X_train = X_train.reshape (-1, img_size, img_size, 1)
y_train = np.array(y_train)

X_val = X_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

X_test = X_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %% [markdown]
# **Data Augmentation**
#
# Getting Train Generator

# %%
image_generator = ImageDataGenerator(
  featurewise_center = False, # set input mean to 0 over the dataset
  samplewise_center = False, # set each sample mean to 0
  featurewise_std_normalization = False, #divide inputs by std of the dataset
  samplewise_std_normalization = False, # divide each input by its std
  zca_whitening=False,  # apply ZCA whitening
  rotation_range =20, #randomly rotate images in the range
  zoom_range = 0.1, #randomly zoom image
  width_shift_range = 0.2, #randomly shift images horizontally
  height_shift_range = 0.2, #randomly shift images vertically
  horizontal_flip = True, #randomly flip images
  vertical_flip = False) #randomly flip images

image_generator.fit(X_train)

# %% [markdown]
# # DATA MODELLING

# %% [markdown]
# Building CNN Model

# %%
from keras.layers import BatchNormalization,MaxPool2D

model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))

model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))

model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))

model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      320
#
#  batch_normalization (Batch  (None, 150, 150, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 75, 75, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  dropout (Dropout)           (None, 75, 75, 64)        0
#
#  batch_normalization_1 (Bat  (None, 75, 75, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 38, 38, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 64)        36928
#
#  batch_normalization_2 (Bat  (None, 38, 38, 64)        256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 19, 19, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 19, 19, 128)       73856
#
#  dropout_1 (Dropout)         (None, 19, 19, 128)       0
#
#  batch_normalization_3 (Bat  (None, 19, 19, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 256)       295168
#
#  dropout_2 (Dropout)         (None, 10, 10, 256)       0
#
#  batch_normalization_4 (Bat  (None, 10, 10, 256)       1024
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 128)               819328
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1246401 (4.75 MB)
# Trainable params: 1245313 (4.75 MB)
# Non-trainable params: 1088 (4.25 KB)
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
history = model.fit(image_generator.flow(X_train, y_train, batch_size=64), epochs=5, validation_data=image_generator.flow(X_val, y_val), callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/5
# 92/92 [==============================] - 576s 6s/step - loss: 0.8830 - accuracy: 0.8171 - val_loss: 3.4410 - val_accuracy: 0.7297 - lr: 0.0010
# Epoch 2/5
# 92/92 [==============================] - 582s 6s/step - loss: 0.3163 - accuracy: 0.8827 - val_loss: 5.4568 - val_accuracy: 0.7297 - lr: 0.0010
# Epoch 3/5
# 92/92 [==============================] - ETA: 0s - loss: 0.2554 - accuracy: 0.9028
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 92/92 [==============================] - 566s 6s/step - loss: 0.2554 - accuracy: 0.9028 - val_loss: 7.7980 - val_accuracy: 0.7297 - lr: 0.0010
# Epoch 4/5
# 92/92 [==============================] - 577s 6s/step - loss: 0.1898 - accuracy: 0.9320 - val_loss: 3.8457 - val_accuracy: 0.7297 - lr: 3.0000e-04
# Epoch 5/5
# 92/92 [==============================] - 593s 6s/step - loss: 0.1786 - accuracy: 0.9343 - val_loss: 2.9373 - val_accuracy: 0.7298 - lr: 3.0000e-04

# %%
print("Loss of the model is - " , model.evaluate(X_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 183/183 [==============================] - 122s 665ms/step - loss: 0.6947 - accuracy: 0.2707
# Loss of the model is -  0.6947450637817383
# 183/183 [==============================] - 134s 733ms/step - loss: 0.6947 - accuracy: 0.2707
# Accuracy of the model is -  27.06625759601593 %

# %%
predictions = (model.predict(X_test) > 0.5).astype("int")
predictions = predictions.reshape(1, -1)[0]
predictions[:5]
# Out:
# 183/183 [==============================] - 125s 681ms/step
# array([1, 1, 1, 1, 1])

# %%
print(predictions)
# Out:
# [0 0 0 ... 0 0 0]

# %%
import sklearn.metrics

print(sklearn.metrics.classification_report(y_test, predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.73      1.00      0.84      4273
#    Normal (Class 1)       1.00      0.00      0.01      1583
#
#            accuracy                           0.73      5856
#           macro avg       0.87      0.50      0.42      5856
#        weighted avg       0.80      0.73      0.62      5856

# %%
import sklearn.metrics
from sklearn.metrics import classification_report

# Assuming 'predictions' and 'y_test' are already defined
print(classification_report(y_test, predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.73      1.00      0.84      4273
#    Normal (Class 1)       1.00      0.00      0.01      1583
#
#            accuracy                           0.73      5856
#           macro avg       0.87      0.50      0.42      5856
#        weighted avg       0.80      0.73      0.62      5856

# %%
cm = confusion_matrix(y_test, predictions)
cm
# Out:
# array([[4273,    0],
#        [1579,    4]])

# %%
cm = pd.DataFrame(cm, index=['0', '1'], columns=['0', '1'])
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues" , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <Axes: >

# %% [markdown]
# # Reference
#
# 1) https://colab.research.google.com/drive/1hDyRJWJeixbGx425_R5f8tnuxf3w2by1
#
# 2) https://drive.google.com/file/d/1219EeGE1XTJVXYaulynJSa3BXGsbNCLx/view
#
# 3) https://www.kaggle.com/code/jonaspalucibarbosa/chest-x-ray-pneumonia-cnn-transfer-learning
